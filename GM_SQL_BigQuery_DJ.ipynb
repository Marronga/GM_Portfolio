# %% [markdown]
# # <font color= blue>From Clicks to Loyalty: Analyzing SXSW 2018 Traffic to Boost 2019 Engagement_ Gaetano Marrone </font>

# %% [markdown]
# ## Scenario
#
# > For this project, our team designed a campaign for the SXSW 2019 festival. We analyzed website traffic data from the March 2018 SXSW festival to understand what type of content to promote. The data included visits to xyxy.com from first-time visitors.
#
# Find out which content could turn these visitors into loyal readers and subscribers. <br>
# Each row in the dataset represented a single page view.

# %% [markdown]
# ## Dataset Structure
#
# ![image.png](attachment:960575be-b825-42de-bb37-baa0bccc9a98.png)

# %% [markdown]
# ## The goal is to answer the following questions:
#
# 1. __What percent of customers returned after the first visit?__  <br>
#
# 2. __What are the top three best-performing stories in each section, by pageviews?__  <br>
#
# 3. __Based on this data, would you choose to promote a Tech story or a Markets story on social media? Why?__  <br>
#
# 4. __Create a visualization exploring the relationship between any of the content characteristics (such as section, author, keywords, etc.) and returning visitors. Additionally, what other interesting stories can you tell with this data?__

# %% [markdown]
# ## SQL Queries (<font color= blue>Google BigQuery</font>)

# %% [markdown]
# ### <font color= blue>1.</font> What percent of customers returned after the first visit?

# %% [markdown]
# ![image.png](attachment:6b4391f6-c1d5-4ac1-8d81-f6589aa18245.png)

# %% [markdown]
# ### <font color= blue>2.</font> What are the top three best-performing stories in each section, by pageviews?

# %% [markdown]
# ![image.png](attachment:7af0b9c7-2e87-4fcc-9afc-fe26701da532.png)

# %% [markdown]
# ### <font color= blue>3.</font> Based on this data, would you choose to promote a Tech story or a Markets story on social media? Why?

# %% [markdown]
# ![image.png](attachment:1d3aa845-dec2-4c89-9047-cab200a6819a.png)

# %% [markdown]
# ### <font color= blue>4.</font> Create a visualization exploring the relationship between any of the content characteristics (such as section, author, keywords, etc.) and returning visitors. Additionally, what other interesting stories can you tell with this data?

# %% [markdown]
# ![image.png](attachment:47319141-b54e-4c50-a6bc-132172c954c5.png)

# %%
# Data project by Gaetano Marrone
